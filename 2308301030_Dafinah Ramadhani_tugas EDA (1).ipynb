# %% [markdown]
# ### Dafinah Ramadhani_23083010030_EDA(A)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("C://Users//ASUS//Documents//Reviews.csv")
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ### Mencari Missing value

# %%
np.sum(df.isnull())
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Asumsikan df adalah DataFrame Anda yang sudah diimpor

# Menghitung jumlah missing values
missing_count = df.isnull().sum()

# Filter kolom dengan missing values
missing_features = missing_count[missing_count > 0]

# Visualisasi
plt.figure(figsize=(10, 6))
sns.barplot(x=missing_features.index, y=missing_features.values, palette='viridis')
plt.title('Jumlah Missing Values per Fitur')
plt.xticks(rotation=45)
plt.ylabel('Jumlah Missing Values')
plt.xlabel('Fitur')
plt.show()

# %%
#menganalisis dan memvisualisasikan korelasi antara fitur-fitur dalam DataFrame
missing_corr = df.isnull().corr()
plt.figure(figsize=(10, 8))
sns.heatmap(missing_corr, annot=True, cmap='coolwarm')
plt.title('Korelasi Missing Values antar Fitur')
plt.show()

# %%
# Perbandingan Distribusi Skor: Kode ini membantu untuk memahami apakah terdapat perbedaan dalam distribusi skor antara entri yang memiliki nilai Summaryyang hilang dan yang tidak hilang.
missing_summary = df[df['Summary'].isnull()]
not_missing_summary = df[df['Summary'].notnull()]

# Bandingkan distribusi score
plt.figure(figsize=(10, 6))
sns.kdeplot(missing_summary['Score'], label='Missing Summary', shade=True, color='red')
sns.kdeplot(not_missing_summary['Score'], label='Not Missing Summary', shade=True, color='green')
plt.title('Distribusi Score untuk Missing dan Not Missing Summary')
plt.legend()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_32996\3108562241.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(missing_summary['Score'], label='Missing Summary', shade=True, color='red')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_32996\3108562241.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(not_missing_summary['Score'], label='Not Missing Summary', shade=True, color='green')

# %%
# menganalisis dan memvisualisasikan distribusi nilai yang hilang
missing_by_target = df.groupby('Score').apply(lambda x: x.isnull().sum())
missing_by_target.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='viridis')
plt.title('Distribusi Missing Values berdasarkan Score')
plt.xlabel('Score')
plt.ylabel('Jumlah Missing Values')
plt.xticks(rotation=0)
plt.show()

# %%
# Analisis Penyebab Nilai Hilang
missing_percentage = df.isnull().mean() * 100
missing_percentage.sort_values(ascending=False, inplace=True)
print(missing_percentage)
# Out:
# Summary                   0.004750
# ProfileName               0.002815
# Id                        0.000000
# ProductId                 0.000000
# UserId                    0.000000
# HelpfulnessNumerator      0.000000
# HelpfulnessDenominator    0.000000
# Score                     0.000000
# Time                      0.000000
# Text                      0.000000
# dtype: float64

# %%
import pandas as pd

# Menghapus baris yang memiliki missing value di kolom ProfileName dan Summary
df_clean = df.dropna(subset=['ProfileName', 'Summary'])
print(df_clean)
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 4                          0                       0      5  1350777600
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text Score_Category
# 0       I have bought several of the Vitality canned d...           High
# 1       Product arrived labeled as Jumbo Salted Peanut...            Low
# 2       This is a confection that has been around a fe...         Medium
# 3       If you are looking for the secret ingredient i...            Low
# 4       Great taffy at a great price.  There was a wid...           High
# ...                                                   ...            ...
# 568449  Great for sesame chicken..this is a good if no...           High
# 568450  I'm disappointed with the flavor. The chocolat...            Low
# 568451  These stars are small, so you can give 10-15 o...           High
# 568452  These are the BEST treats for training and rew...           High
# 568453  I am very satisfied ,product is as advertised,...           High
#
# [568454 rows x 11 columns]

# %%
import pandas as pd

# Misalkan df adalah DataFrame yang berisi data Anda
# Mengisi missing value di kolom ProfileName dan Summary dengan modus

for column in ['ProfileName', 'Summary']:
    df[column].fillna(df[column].mode()[0], inplace=True)

# Memeriksa apakah masih ada missing value
print(df.isnull().sum())
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Summary                   0
# Text                      0
# Score_Category            0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Misalkan df adalah DataFrame yang berisi data Anda
# Menentukan missing values
missing_values = df.isnull().sum()

# Menyaring hanya fitur yang memiliki missing value lebih dari 0
missing_values = missing_values[missing_values > 0]

# Visualisasi missing value dengan bar chart
plt.figure(figsize=(10, 6))
plt.bar(missing_values.index, missing_values.values, color='skyblue')
plt.title('Missing Values in Features', fontsize=16)
plt.xlabel('Features', fontsize=12)
plt.ylabel('Number of Missing Values', fontsize=12)
plt.xticks(rotation=90)  # Memutar label sumbu X agar terlihat jelas
plt.tight_layout()  # Menyempurnakan layout agar label tidak terpotong
plt.show()

# %% [markdown]
# ## dummy variabel

# %%
import pandas as pd

# Baca data
df = pd.read_csv("C://Users//ASUS//Documents//Reviews.csv")

# Cek nama kolom
print(df.columns)

# Cek jumlah nilai unik pada kolom yang relevan
print(df['Summary'].nunique()) 


df['Score_Category'] = pd.cut(df['Score'], bins=[0, 2, 4, 5], labels=['Low', 'Medium', 'High'])

# Melakukan dummy encoding pada kategori yang baru dibuat
df_dummies = pd.get_dummies(df, columns=['Score_Category'], drop_first=True)

# Melihat data setelah konversi
print(df_dummies.head())
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')
# 295742
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
#
#    Score_Category_Medium  Score_Category_High
# 0                      0                    1
# 1                      0                    0
# 2                      1                    0
# 3                      0                    0
# 4                      0                    1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cek nama kolom untuk memastikan
print(df_dummies.columns)

# Visualisasi distribusi kategori
plt.figure(figsize=(10, 6))
sns.countplot(x='Score_Category_High', data=df_dummies)  
plt.title('Distribusi Kategori Skor Tinggi')
plt.show()

# Heatmap korelasi
plt.figure(figsize=(10, 8))
correlation_matrix = df_dummies.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasi Fitur')
plt.show()
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text',
#        'Score_Category_Medium', 'Score_Category_High'],
#       dtype='object')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_30540\778479051.py:15: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_dummies.corr()

# %%
# Menghitung panjang teks
df_dummies['Text_Length'] = df_dummies['Text'].apply(lambda x: len(x.split()))

# Visualisasi panjang teks
plt.figure(figsize=(10, 6))
sns.histplot(df_dummies['Text_Length'], bins=30)
plt.title('Distribusi Panjang Teks Ulasan')
plt.xlabel('Panjang Teks (jumlah kata)')
plt.ylabel('Frekuensi')
plt.show()

# Analisis hubungan panjang teks dan skor
plt.figure(figsize=(10, 6))
sns.boxplot(x='Score', y='Text_Length', data=df_dummies)
plt.title('Hubungan Panjang Teks dengan Skor')
plt.xlabel('Skor')
plt.ylabel('Panjang Teks')
plt.show()

# %% [markdown]
# ## Outlier

# %%
import pandas as pd

# Misalkan df adalah DataFrame Anda
Q1 = df['Score'].quantile(0.25)
Q3 = df['Score'].quantile(0.75)
IQR = Q3 - Q1

# Menentukan batas bawah dan atas
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Mencari outlier
outliers = df[(df['Score'] < lower_bound) | (df['Score'] > upper_bound)]
print(outliers)
# Out:
#             Id   ProductId          UserId      ProfileName  \
# 1            2  B00813GRG4  A1D87F6ZCVE5NK           dll pa
# 3            4  B000UA0QIQ  A395BORC6FGVXV             Karl
# 12          13  B0009XLVG0   A327PCT23YH90               LT
# 16          17  B001GVISJM  A3KLWF6WQ5BNYO   Erica Neathery
# 26          27  B001GVISJM  A3RXAU2N8KV45G           lady21
# ...        ...         ...             ...              ...
# 568433  568434  B003XUL27E  A1JUG9WCN1A52Z       maudlin666
# 568434  568435  B003XUL27E   ABGQPE97ZVYJ3  Katherine Kelly
# 568435  568436  B003XUL27E  A2PSB4WQHH46HN         carlyowu
# 568446  568447  B001EO7N10  A2P9W8T7NTLG2Z             Andy
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5        R. Sawyer
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 1                          0                       0      1  1346976000
# 3                          3                       3      2  1307923200
# 12                         1                       1      1  1339545600
# 16                         0                       0      2  1348099200
# 26                         0                       1      1  1332633600
# ...                      ...                     ...    ...         ...
# 568433                     0                       0      1  1311638400
# 568434                     0                       0      2  1306368000
# 568435                     0                       2      2  1285718400
# 568446                     0                       0      2  1328918400
# 568450                     0                       0      2  1331251200
#
#                                      Summary  \
# 1                          Not as Advertised
# 3                             Cough Medicine
# 12      My Cats Are Not Fans of the New Food
# 16                                poor taste
# 26                           Nasty No flavor
# ...                                      ...
# 568433                      Tastes horrible!
# 568434                           Not so good
# 568435               Where's the tortellini?
# 568446                           Mixed wrong
# 568450                          disappointed
#
#                                                      Text Score_Category
# 1       Product arrived labeled as Jumbo Salted Peanut...            Low
# 3       If you are looking for the secret ingredient i...            Low
# 12      My cats have been happily eating Felidae Plati...            Low
# 16      I love eating them and they are good for watch...            Low
# 26      The candy is just red , No flavor . Just  plan...            Low
# ...                                                   ...            ...
# 568433  I just bought this soup today at my local groc...            Low
# 568434  This soup is mostly broth. Although it has a k...            Low
# 568435  It is mostly broth, with the advertised 3/4 cu...            Low
# 568446  I had ordered some of these a few months back ...            Low
# 568450  I'm disappointed with the flavor. The chocolat...            Low
#
# [82037 rows x 11 columns]

# %%
from scipy import stats

# Menghitung Z-Score
z_scores = stats.zscore(df['Score'])
abs_z_scores = abs(z_scores)

# Menentukan threshold
threshold = 3

# Mencari outlier
outliers = df[abs_z_scores > threshold]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Id, ProductId, UserId, ProfileName, HelpfulnessNumerator, HelpfulnessDenominator, Score, Time, Summary, Text, Score_Category]
# Index: []

# %% [markdown]
# ### kategorisasi variabel

# %%
import pandas as pd

# Memuat dataset dari file CSV (sesuaikan path ke file yang Anda miliki)
df = pd.read_csv("C://Users//ASUS//Documents//Reviews.csv")

# Menampilkan beberapa baris pertama dari data untuk memastikan data dimuat
print(df.head())

# Definisi bins dan labels untuk Score
score_bins = [0, 2, 4, 5]  # Misalnya membagi score menjadi tiga kategori: 0-2, 3-4, dan 5
score_labels = ['Low', 'Medium', 'High']  # Label untuk kategori skor

# Membuat kolom kategori berdasarkan nilai Score
df['Score_Category'] = pd.cut(df['Score'], bins=score_bins, labels=score_labels, right=False)

# Menampilkan beberapa baris pertama dengan kolom yang relevan
print(df[['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator', 
          'HelpfulnessDenominator', 'Score', 'Score_Category']].head())
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score Score_Category
# 0                     1                       1      5            NaN
# 1                     0                       0      1            Low
# 2                     1                       1      4           High
# 3                     3                       3      2         Medium
# 4                     0                       0      5            NaN

# %%
# Membuat kategori berdasarkan Score
df['Score_Category'] = pd.cut(df['Score'], bins=[0, 2, 4, 5], labels=['Low', 'Medium', 'High'])
print(df['Score_Category'].value_counts())
# Out:
# High      363122
# Medium    123295
# Low        82037
# Name: Score_Category, dtype: int64

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv("C://Users//ASUS//Documents//Reviews.csv")

# Specify the numeric columns to be analyzed
numeric_columns = ['HelpfulnessNumerator', 'HelpfulnessDenominator', 'Score']

# 1. Visualize the distribution before scaling
plt.figure(figsize=(12, 8))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i) 
    sns.histplot(df[column], kde=True) 
    plt.title(f'{column} - Before Scaling')
plt.tight_layout()
plt.show()

# 2. Transform the data with StandardScaler
scaler = StandardScaler()
df_scaled = df.copy()  
df_scaled[numeric_columns] = scaler.fit_transform(df[numeric_columns]) 

# 3. Visualize the distribution after scaling
plt.figure(figsize=(12, 8))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df_scaled[column], kde=True)
    plt.title(f'{column} - After Scaling')
plt.tight_layout()
plt.show()
